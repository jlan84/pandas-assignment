# %%
import pandas as pd
from numpy.random import randn

# %% [markdown]
# ### Plotting using pandas

# %%
import matplotlib.pyplot as plt
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
# %matplotlib inline # create plot inside notebook

# %%
df.columns
# Out:
# Index([u'index', 0, 1, 2, 3, 4, u'state'], dtype='object')

# %%
df[0].hist(grid = False, bins=11)
plt.xlabel("0")
plt.ylabel("frequecy")
# Out:
# /home/patanjalichanakya/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family [u'monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/patanjalichanakya/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1292: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
# /home/patanjalichanakya/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1292: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
df = pd.read_csv('data/playgolf.csv', delimiter='|' )
print df.head()
# Out:
#          Date   Outlook  Temperature  Humidity  Windy      Result
# 0  07-01-2014     sunny           85        85  False  Don't Play
# 1  07-02-2014     sunny           80        90   True  Don't Play
# 2  07-03-2014  overcast           83        78  False        Play
# 3  07-04-2014      rain           70        96  False        Play
# 4  07-05-2014      rain           68        80  False        Play

# %%
df.hist(['Temperature','Humidity'],bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f538421c2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5384173110>]], dtype=object)
# /home/patanjalichanakya/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1292: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=x-large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
df[['Temperature','Humidity']].plot(kind='box')

# %%
df[['Temperature','Humidity']].plot(kind='line')

# %%
df[['Temperature','Humidity']].plot(kind='barh')

# %%
df.plot('Temperature', 'Humidity', kind='scatter', c = "red",figsize=(10,10))

# %%
groups=df.groupby('Outlook')

# %%
fig, ax = plt.subplots()

ax.margins(0.05)
for name, group in groups:
    ax.plot(group.Temperature, group.Humidity, marker='o', linestyle='--', ms=5, label=name)
ax.legend(numpoints=1, loc='lower right')
ax.set_xlabel("Temp")
plt.show()

# %% [markdown]
# ### EDA

# %%
df['Outlook'].value_counts()
# Out:
# rain        5
# sunny       5
# overcast    4
# dtype: int64

# %%
pd.scatter_matrix(df, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5383ca8690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5383b2e810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5383ab0610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5383a16a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5383999a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53839bab90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f538388b6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f538380f410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53837f1b50>]], dtype=object)
# /home/patanjalichanakya/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1292: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=8.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
df.Outlook.unique()
# Out:
# array(['sunny', 'overcast', 'rain'], dtype=object)

# %%
df[['Outlook','Result']].apply(lambda x: x.value_counts())
# Out:
#             Outlook  Result
# Don't Play      NaN       5
# Play            NaN       9
# overcast          4     NaN
# rain              5     NaN
# sunny             5     NaN

# %%
pd.crosstab(df['Outlook'], df['Result'])
# Out:
# Result    Don't Play  Play
# Outlook
# overcast           0     4
# rain               2     3
# sunny              3     2

# %%
pd.crosstab(df['Outlook'], df['Result']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# Result    Don't Play  Play
# Outlook
# overcast         0.0   1.0
# rain             0.4   0.6
# sunny            0.6   0.4

# %%
pd.crosstab(df['Outlook'], df['Result']).apply(lambda c: c/c.sum(), axis=0)
# Out:
# Result    Don't Play      Play
# Outlook
# overcast         0.0  0.444444
# rain             0.4  0.333333
# sunny            0.6  0.222222

# %%
df.cov()
# Out:
#             Temperature  Humidity      Windy
# Temperature    43.18681  17.67033   -1.10989
# Humidity       17.67033  96.83516  -1.285714
# Windy          -1.10989 -1.285714  0.2637363

# %%
df.corr()
# Out:
#              Temperature  Humidity     Windy
# Temperature     1.000000  0.273245 -0.328866
# Humidity        0.273245  1.000000 -0.254415
# Windy          -0.328866 -0.254415  1.000000

# %%
temp_humidity = df[['Temperature', 'Humidity']].corr()
temp_humidity
# Out:
#              Temperature  Humidity
# Temperature     1.000000  0.273245
# Humidity        0.273245  1.000000

# %%
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 15)
allcorr = df.corr()
plt.imshow(allcorr, cmap='YlOrRd', interpolation='none');
plt.colorbar()
plt.xticks(range(len(allcorr)), allcorr.columns)
plt.yticks(range(len(allcorr)), allcorr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7f53834fc5d0>,
#   <matplotlib.axis.YTick at 0x7f5383491c10>,
#   <matplotlib.axis.YTick at 0x7f53833f6390>],
#  <a list of 3 Text yticklabel objects>)
