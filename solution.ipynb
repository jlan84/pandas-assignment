# %%
import pandas as pd
import math, pdb, json
import numpy as np
import matplotlib.pyplot as plt

# allows for matplotlib plots to be embedded directly inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Library/Python/2.7/site-packages/pytz/__init__.py:31: UserWarning: Module argparse was already imported from /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/argparse.py, but /Library/Python/2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
product45 = pd.read_json('data/products_1000.json')

# %%
import csv

file = json.load(open('data/products.json'))
out = csv.writer(open("prod_45.csv", "wb+")) 
for k , rec in file.items():
    for rev in rec['reviews']:
        out.writerow([rec['group'], rev["date"], rev["rating"]])

# %%
file
# Out:
# {u'124': {u'asin': u'B0000060TP',
#   u'group': u'Video',
#   u'id': 124,
#   u'review_text': [u"...It is scary - Dink and friends are often being chased by T-Rex, who roars like a lion - and yet my son really wants/needs to watch it. The animation is done by the Hanna-Barbera studios of my childhood. The video contains 5 or so stories about Dink and his friends' adventures as little dinosaurs. The stories teach simple lessons about helping others and the dangers of practical jokes. Although, I basically think this video is fine, I would have preferred something less intense. That's not to say my son would prefer that though!",
#    u'My Kid loved all of the Dink the dinosuar movies I would give them all 5 stars.',
#    u'This is a good one shows kids how to treat other people and how you should see people good cartoon'],
#   u'reviews': [{u'customer': u'A3V32WYWUGVL8D',
#     u'date': u'2000-10-11',
#     u'helpful': u'3',
#     u'rating': u'5',
#     u'votes': u'5'},
# ...

# %%
df = product45

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, asin to title
# Data columns (total 45 columns):
# 124    7  non-null values
# 156    7  non-null values
# 169    7  non-null values
# 180    7  non-null values
# 190    7  non-null values
# 205    7  non-null values
# 229    7  non-null values
# 251    7  non-null values
# 254    7  non-null values
# 306    7  non-null values
# 391    7  non-null values
# 410    7  non-null values
# 415    7  non-null values
# 442    7  non-null values
# 499    7  non-null values
# 555    7  non-null values
# 589    7  non-null values
# 59     7  non-null values
# 656    7  non-null values
# 669    7  non-null values
# 679    7  non-null values
# 71     7  non-null values
# 730    7  non-null values
# 741    7  non-null values
# 748    7  non-null values
# 758    7  non-null values
# 770    7  non-null values
# 786    7  non-null values
# 81     7  non-null values
# 84     7  non-null values
# 854    7  non-null values
# ...

# %%
def expand(frame):
    return pd.DataFrame(frame['reviews'])

df.apply(expand)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-35-f6305a7cd452> in <module>()
#       2     return pd.DataFrame(frame['reviews'])
#       3
# ----> 4 df.apply(expand)
#
# /Library/Python/2.7/site-packages/ipython-1.0.0_dev-py2.7.egg/IPython/core/displayhook.pyc in __call__(self, result)
#     245             self.start_displayhook()
#     246             self.write_output_prompt()
# --> 247             format_dict, md_dict = self.compute_format_data(result)
#     248             self.write_format_data(format_dict, md_dict)
#     249             self.update_user_ns(result)
#
# /Library/Python/2.7/site-packages/ipython-1.0.0_dev-py2.7.egg/IPython/core/displayhook.pyc in compute_format_data(self, result)
#     155
#     156         """
# --> 157         return self.shell.display_formatter.format(result)
#     158
# ...
